# %% [markdown]
# # Project 1

# %%
import pandas as pd

pd.options.display.max_rows = 1000
df=pd.read_csv("https://data.cityofnewyork.us/resource/k397-673e.csv")
df
# Out:
#      fiscal_year  payroll_number                agency_name        last_name  \
# 0           2024              67  ADMIN FOR CHILDREN'S SVCS           VIRUET
# 1           2024              67  ADMIN FOR CHILDREN'S SVCS         SCATURRO
# 2           2024              67  ADMIN FOR CHILDREN'S SVCS           TAYLOR
# 3           2024              67  ADMIN FOR CHILDREN'S SVCS            BERRY
# 4           2024              67  ADMIN FOR CHILDREN'S SVCS       AKINSULIRE
# 5           2024              67  ADMIN FOR CHILDREN'S SVCS  OKONJI-RODRIGUE
# 6           2024              67  ADMIN FOR CHILDREN'S SVCS          SHIRLEY
# 7           2024              67  ADMIN FOR CHILDREN'S SVCS          ANDREWS
# 8           2024              67  ADMIN FOR CHILDREN'S SVCS            CHERY
# 9           2024              67  ADMIN FOR CHILDREN'S SVCS         GRIFFITH
# 10          2024              67  ADMIN FOR CHILDREN'S SVCS       HALIBURTON
# ...

# %%
mean_value = df['base_salary'].mean()
mean_value
# Out:
# 67179.73715999999

# %%
median_value = df['base_salary'].median()
median_value
# Out:
# 62043.0

# %%
mode_value = df['base_salary'].mode()[0]
mode_value
# Out:
# 57127.0

# %%
df.columns
# Out:
# Index(['fiscal_year', 'payroll_number', 'agency_name', 'last_name',
#        'first_name', 'mid_init', 'agency_start_date', 'work_location_borough',
#        'title_description', 'leave_status_as_of_june_30', 'base_salary',
#        'pay_basis', 'regular_hours', 'regular_gross_paid', 'ot_hours',
#        'total_ot_paid', 'total_other_pay'],
#       dtype='object')

# %%
df["base_salary"] = df["base_salary"] / 1e6
df = df[df["title_description"].notna()]

yearly_count = df.groupby(["work_location_borough", "title_description"])["base_salary"].sum().reset_index()

yearly_count
# Out:
#    work_location_borough                                  title_description  \
# 0                  BRONX                                              *COOK
# 1                  BRONX                                       *SENIOR COOK
# 2                  BRONX  ADMINISTRATIVE DIRECTOR OF RESIDENTIAL CHILD CARE
# 3                  BRONX         ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES
# 4                  BRONX                                    AGENCY ATTORNEY
# 5                  BRONX                            AGENCY ATTORNEY INTERNE
# 6                  BRONX             ASSOCIATE YOUTH DEVELOPMENT SPECIALIST
# 7                  BRONX                                           CHAPLAIN
# 8                  BRONX                        CHILD AND FAMILY SPECIALIST
# 9                  BRONX                        CHILD PROTECTIVE SPECIALIST
# 10                 BRONX             CHILD PROTECTIVE SPECIALIST SUPERVISOR
# ...

# %%
import plotly.express as px

px.histogram(
    yearly_count, 
    x="title_description", 
    y="base_salary", 
    color="work_location_borough",
    title="Salary Counts by Position", 
    labels={"title_description":"Position Titile", "base_salary": "Salary Amount"}
)
